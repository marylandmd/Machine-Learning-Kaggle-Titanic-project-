# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv(r"C:\Users\Cun\Documents\Kaggle\titanic\train.csv")
test_df = pd.read_csv(r"C:\Users\Cun\Documents\Kaggle\titanic\test.csv")

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_df.set_index(train_df.PassengerId, inplace=True)

# %%
train_df.head()
# Out:
#              PassengerId  Survived  Pclass  \
# PassengerId
# 1                      1         0       3
# 2                      2         1       1
# 3                      3         1       3
# 4                      4         1       1
# 5                      5         0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# ...

# %%
train_df.drop('PassengerId', axis =1)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
test_df = pd.read_csv(r"C:\Users\Cun\Downloads\titanic1\test.csv", index_col = 'PassengerId')

# %%
test_df.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # 1. Feature Classification: Categorical vs Numerical

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.5+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    418 non-null    int64
#  1   Name      418 non-null    object
#  2   Sex       418 non-null    object
#  3   Age       332 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Ticket    418 non-null    object
#  7   Fare      417 non-null    float64
#  8   Cabin     91 non-null     object
#  9   Embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
train_df["Survived"] = train_df["Survived"].astype("category")

# %%
train_df["Survived"].dtype
# Out:
# CategoricalDtype(categories=[0, 1], ordered=False, categories_dtype=int64)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: category(1), float64(2), int64(4), object(5)
# memory usage: 84.5+ KB

# %%
features = ["Pclass", "Sex", "SibSp", "Parch", "Embarked"]
def convert_cat(df, features):
    for feature in features:
        df[feature] = df[feature].astype("category")
convert_cat(train_df, features)
convert_cat(test_df, features)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    category
#  7   Parch        891 non-null    category
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    category
# dtypes: category(6), float64(2), int64(1), object(3)
# memory usage: 55.1+ KB

# %%
train_df.describe (include=['category'])
# Out:
#         Survived  Pclass   Sex  SibSp  Parch Embarked
# count        891     891   891    891    891      889
# unique         2       3     2      7      7        3
# top            0       3  male      0      0        S
# freq         549     491   577    608    678      644

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 3.1: Correlating categorical features
# - Categorical: `Survived`, `Sex`, `Embarked`, `PClass`, `SibSp`, `Parch`

# %% [markdown]
# #### Target Variable: `Survived`

# %%
train_df["Survived"].value_counts(normalize=True).to_frame()
# Out:
#           proportion
# Survived
# 0           0.616162
# 1           0.383838

# %% [markdown]
# #### `Sex`

# %%
train_df["Sex"].value_counts(normalize=True).to_frame()
# Out:
#         proportion
# Sex
# male      0.647587
# female    0.352413

# %%
sns.countplot(data=train_df, x='Sex', hue='Survived', palette='Blues')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
cols= ['Sex', 'Embarked', 'Pclass','SibSp', 'Parch']

n_rows = 2
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_cols*4.4, n_rows*4.7))
fig.suptitle("Survival Rate by Feature", fontsize=16, fontweight='bold') 


for r in range (0, n_rows):
    for c in range (0, n_cols):
        i = r*n_cols + c
        if i<len(cols):
            ax_i = ax[r,c]
            sns.countplot(data= train_df, x=cols[i], hue="Survived", palette="Blues", ax=ax_i)
            ax_i.set_title(f"Figure {i+1}: Survival Rate vs {cols[i]}")
            ax_i.legend(title='', loc='upper right', labels=['Not Survived', 'Survived'])
ax.flat[-1].set_visible(False)
plt.tight_layout
plt.show()

# %% [markdown]
# ### Observation:
# * Survival Rate:
#   - Fig 1: Female survival rate > male
#   - Fig 2: Most people embarked on Southampton, and also had the highest people not survived
#   - Fig 3: 1st class higher survival rate
#   - Fig 4: People going with 0 `SibSp` are mostly not survived. The number of passenger with 1-2 family members has a better chance of survival
#   - Fig 5: People going with 0 `Parch` are mostly not survived.

# %% [markdown]
# ## 3.2: EDA for Numerical Features
# - Numerical Features: `Age` and `Fare`

# %% [markdown]
# ## `Age`

# %%
sns.histplot(data=train_df, x="Age", hue='Survived', bins = 40, kde=True)
plt.show()

# %% [markdown]
# ### Observation:
#   - Majority passengers were from 18 - 40 ages
#   - Children had more chance to survive than other ages

# %% [markdown]
# ## `Fare`

# %%
train_df["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
sns.histplot(data=train_df, x='Fare', hue='Survived', bins=40, palette= 'Blues')
plt.show()

# %% [markdown]
# #4. Feature Engineering and Data Wrangling

# %%
fare_categories = ['Economics', 'Standard', 'Expensive', 'Luxury']
quartile_data = pd.qcut(train_df['Fare'], 4, labels=fare_categories)

sns.countplot(x=quartile_data, hue=train_df['Survived'], palette="Blues")
plt.show()

# %% [markdown]
# # 4. Feature Engineering & Data Wrangling

# %% [markdown]
# ### `Name`

# %%
train_df['Name'].head(10)
# Out:
# PassengerId
# 1                               Braund, Mr. Owen Harris
# 2     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                Heikkinen, Miss. Laina
# 4          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                              Allen, Mr. William Henry
# 6                                      Moran, Mr. James
# 7                               McCarthy, Mr. Timothy J
# 8                        Palsson, Master. Gosta Leonard
# 9     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
import re
def extract_title(name):
    p = re.compile(r",([\w\s]+)\.")
    return p.search(name).groups(1)[0].strip()

train_df['Title'] = train_df['Name'].apply(lambda name: extract_title(name))
train_df['Title'].value_counts()

test_df['Title'] = test_df['Name'].apply(lambda name: extract_title(name))
test_df['Title'].value_counts()
# Out:
# Title
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Ms          1
# Dr          1
# Dona        1
# Name: count, dtype: int64

# %%
def group_title (title):
    if title in ['Mr','Mrs','Miss','Master']:
        return title
    elif title == "Ms":
        return "Miss"
    else:
        return "Others"
train_df['Title'] = train_df['Title'].apply(lambda title: group_title(title))
test_df['Title'] = test_df['Title'].apply(lambda title: group_title(title))

# %%
sns.countplot(data=train_df, x='Title', hue='Survived')
plt.show()

# %% [markdown]
# ## `Family`

# %% [markdown]
# ### `SibSp`, `Parch`

# %%
train_df['Family_Size'] = train_df['SibSp'].astype('int') + train_df['Parch'].astype('int')+1
test_df['Family_Size'] = test_df['SibSp'].astype('int') + test_df['Parch'].astype('int')+1

# %%
train_df['Family_Cat'] = pd.cut(train_df['Family_Size'], bins=[0,1,4,6,20], labels = ['Solo', 'Small', 'Medium', 'Large'])
test_df['Family_Cat']  = pd.cut(train_df['Family_Size'], bins=[0,1,4,6,20], labels = ['Solo', 'Small', 'Medium', 'Large'])

# %%
sns.countplot(data=train_df, x='Family_Cat', hue='Survived')
plt.show()

# %% [markdown]
# ## 4.2: Data Wrangling: Cleaning & Fill missing data

# %%
num_features = ['Age', 'Fare']
cat_features = ['Sex', 'Pclass', 'Embarked', 'Title', 'Family_Cat']
feature_cols = num_features + cat_features
print(feature_cols, '\n')
# Out:
# ['Age', 'Fare', 'Sex', 'Pclass', 'Embarked', 'Title', 'Family_Cat']

# %%
def display_missing(df, feature_cols):
    n_rows = df.shape[0]
    for col in feature_cols:
        missing_count = df[col].isnull().sum()
        if missing_count > 0:
            print(f"{col} has {missing_count* 100/n_rows:.2f}% missing values.")

# %%
display_missing(train_df, feature_cols)
# Out:
# Age has 19.87% missing values.
# Embarked has 0.22% missing values.

# %%
display_missing(test_df, feature_cols)
# Out:
# Age has 20.57% missing values.
# Fare has 0.24% missing values.
# Family_Cat has 100.00% missing values.

# %% [markdown]
# ### Filling missing values

# %% [markdown]
# ### Age
# - Filling missing values with `Median` of the whole dataset

# %%
age_by_sex_pclass = train_df.groupby(['Sex', 'Pclass'])['Age'].median()
# Out:
# C:\Users\Cun\AppData\Local\Temp\ipykernel_3248\1729732706.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_by_sex_pclass = train_df.groupby(['Sex', 'Pclass'])['Age'].median()

# %%
age_by_sex_pclass
# Out:
# Sex     Pclass
# female  1         35.0
#         2         28.0
#         3         21.5
# male    1         40.0
#         2         30.0
#         3         25.0
# Name: Age, dtype: float64

# %%
display_missing(train_df, feature_cols)
display_missing(test_df, feature_cols)
# Out:
# Age has 19.87% missing values.
# Embarked has 0.22% missing values.
# Age has 20.57% missing values.
# Fare has 0.24% missing values.
# Family_Cat has 100.00% missing values.

# %%
X = train_df[feature_cols]
y = train_df['Survived']

# %%
X_test = test_df[feature_cols]

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
num_transformer = Pipeline(steps =[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

cat_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encode', OneHotEncoder(handle_unknown= 'ignore'))
])

# %%
preprocessor = ColumnTransformer(transformers=
[
    ('num', num_transformer, num_features),
    ('cat', cat_transformer, cat_features)
])

# %%
preprocessor.fit(X)
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['Age', 'Fare']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encode',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['Sex', 'Pclass', 'Embarked', 'Title',
#                                   'Family_Cat'])])

# %%
X= preprocessor.transform(X)

# %%
X_test = preprocessor.transform(X_test)

# %% [markdown]
# # 5. Model Training

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(X,y, test_size = 0.2)

# %%
X_train.shape, X_val.shape
# Out:
# ((712, 19), (179, 19))

# %%
X_test.shape
# Out:
# (418, 19)

# %% [markdown]
# ## Binary classification

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, classification_report, confusion_matrix

# %%
log_reg = LogisticRegression(solver='liblinear', max_iter=1000)
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %%
log_reg.score(X_val, y_val)
# Out:
# 0.8435754189944135

# %%
y_pred = log_reg.predict(X_val)

# %%
precision_score(y_val, y_pred), recall_score(y_val, y_pred)
# Out:
# (0.8615384615384616, 0.7466666666666667)

# %%
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87       104
#            1       0.86      0.75      0.80        75
#
#     accuracy                           0.84       179
#    macro avg       0.85      0.83      0.84       179
# weighted avg       0.85      0.84      0.84       179

# %%
poly = PolynomialFeatures(degree=3)
poly_features_X_train = poly.fit_transform(X_train)
poly_features_X_val = poly.transform(X_val)

# %%
poly_log_reg = LogisticRegression(solver='liblinear', max_iter=1000)
poly_log_reg.fit(poly_features_X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %%
poly_log_reg.score(poly_features_X_val, y_val)
# Out:
# 0.8100558659217877

# %%
# decision Tree

# %%
decision_tree = DecisionTreeClassifier(criterion = 'entropy', max_depth = 5, random_state=2025)
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=2025)

# %%
decision_tree.score(X_val, y_val)
# Out:
# 0.8100558659217877

# %% [markdown]
# ## 5.1: Cross-validation

# %%
from sklearn.model_selection import cross_val_score

# %%
log_reg_cv = LogisticRegression(solver='liblinear', max_iter = 1000)
dt_cv = DecisionTreeClassifier(criterion = 'entropy', max_depth = 5, random_state=2025)

lr_scores = cross_val_score(log_reg_cv, X, y, scoring='accuracy', cv=5)

# %%
lr_scores.mean(), lr_scores.std()
# Out:
# (0.8237838177138912, 0.020974212551877137)

# %%
dt_scores = cross_val_score(dt_cv, X, y, scoring='accuracy', cv=5)

# %%
dt_scores.mean(), dt_scores.std()
# Out:
# (0.8137153976523759, 0.012117974007974633)

# %% [markdown]
# ## 5.2: Baseline Model Comparison

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.svm import LinearSVC, SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
seed = 2025
models = [
    LinearSVC(max_iter = 12000, random_state=seed),
    SVC (random_state=seed),
    KNeighborsClassifier(metric='minkowski', p=2),
    LogisticRegression(solver='liblinear', max_iter=1000),
    DecisionTreeClassifier(random_state=seed),
    RandomForestClassifier(random_state=seed),
    ExtraTreesClassifier(),
    AdaBoostClassifier(),
    XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=seed)
]

# %%
from sklearn.model_selection import StratifiedKFold
def generate_baseline_results(models, X, y, metrics, cv=5, plot_results=False):
# define k-fold:
    kfold = StratifiedKFold(cv, shuffle=True, random_state = seed)
    entries = []
    for model in models:
        model_name = model.__class__.__name__
        #(model_name)
        
        scores = cross_val_score(model, X,y, scoring=metrics, cv=kfold)
        for fold_idx, score in enumerate(scores):
            entries.append((model_name, fold_idx, score))

    cv_df = pd.DataFrame (entries, columns = ['model_name', 'fold_id', 'accuracy_score'])

    if plot_results:
        sns.boxplot(x='model_name', y='accuracy_score', data= cv_df, color='lightblue', showmeans = True)
        plt.title("Boxplot of Base-Line Model Accuracy using 5-fold cross-validation")
        plt.xticks(rotation = 45)
        plt.show()

    #Summary result:
    mean = cv_df.groupby('model_name')['accuracy_score'].mean()
    std = cv_df.groupby('model_name')['accuracy_score'].std()

    baseline_results = pd.concat([mean, std], axis = 1, ignore_index= True)
    baseline_results.columns = ['Mean', 'Standard Deviation']

    #Sort by accuracy
    baseline_results.sort_values(by=['Mean'], ascending= False, inplace= True)
    return baseline_results
    #return cv_df

generate_baseline_results(models, X, y, metrics = 'accuracy', cv=5, plot_results = True)
# Out:
# C:\Users\Cun\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [20:28:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Cun\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [20:28:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Cun\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [20:28:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\Cun\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [20:28:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
# ...

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, GridSearchCV
import numpy as np
import pandas as pd

# Pipeline: Polynomial -> Logistic
pipe_poly_log = make_pipeline(
    PolynomialFeatures(include_bias=False),             
    LogisticRegression(solver='liblinear', max_iter=2000) 
)

param_grid_poly = {
    'polynomialfeatures__degree': [2, 3],
    'polynomialfeatures__interaction_only': [False, True],
    'logisticregression__penalty': ['l1', 'l2'],
    'logisticregression__C': np.logspace(-2, 2, 9)  # 0.01 → 100
}

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

gs_poly = GridSearchCV(
    estimator=pipe_poly_log,
    param_grid=param_grid_poly,
    scoring='accuracy',  
    cv=skf,
    n_jobs=-1,
    verbose=1,
    refit=True         
)

gs_poly.fit(X, y)
print("PolyLog best CV:", gs_poly.best_score_)
print("PolyLog best params:", gs_poly.best_params_)


y_pred_test_poly = gs_poly.best_estimator_.predict(X_test)
submission_poly = pd.DataFrame({
    "PassengerId": test_df.index,
    "Survived": y_pred_test_poly.astype(int)
})
submission_poly.to_csv("submission_poly_logreg_tuned.csv", index=False)
print("Saved: submission_poly_logreg_tuned.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 33
#      21 skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
#      23 gs_poly = GridSearchCV(
#      24     estimator=pipe_poly_log,
#      25     param_grid=param_grid_poly,
#    (...)
#      30     refit=True
#      31 )
# ---> 33 gs_poly.fit(X, y)
#      34 print("PolyLog best CV:", gs_poly.best_score_)
#      35 print("PolyLog best params:", gs_poly.best_params_)
#
# NameError: name 'X' is not defined

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, GridSearchCV
import numpy as np
import pandas as pd

pipe_svc = SVC(kernel='rbf', probability=False)
param_grid_svc = {
    'C': np.logspace(-2, 2, 9),      
    'gamma': ['scale', 0.01, 0.03, 0.1, 0.3, 1.0],
}

gs_svc = GridSearchCV(
    estimator=pipe_svc,
    param_grid=param_grid_svc,
    scoring='accuracy',
    cv=skf,
    n_jobs=-1,
    verbose=1,
    refit=True
)
gs_svc.fit(X, y)
print("SVC best CV:", gs_svc.best_score_)
print("SVC best params:", gs_svc.best_params_)

y_pred_test_svc = gs_svc.best_estimator_.predict(X_test)
submission_svc = pd.DataFrame({
    "PassengerId": test_df.index,
    "Survived": y_pred_test_svc.astype(int)
})
submission_svc.to_csv("submission_svc_tuned.csv", index=False)
print("Saved: submission_svc_tuned.csv")
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# SVC best CV: 0.8361308141359614
# SVC best params: {'C': 1.0, 'gamma': 0.1}
# ✅ Saved: submission_svc_tuned.csv

# %%
candidates = [
    ("PolyLog", gs_poly.best_score_, gs_poly.best_estimator_),
    ("SVC",     gs_svc.best_score_,  gs_svc.best_estimator_)
]

best_name, best_cv, best_est = max(candidates, key=lambda x: x[1])
print(f"Best model: {best_name} | CV={best_cv:.4f}")

y_pred_test_best = best_est.predict(X_test)
submission_best = pd.DataFrame({
    "PassengerId": test_df.index,
    "Survived": y_pred_test_best.astype(int)
})
submission_best.to_csv(f"submission_{best_name}_best.csv", index= False, sep=",")
print(f"Saved: submission_{best_name}_best.csv")
# Out:
# 🏆 Best model: PolyLog | CV=0.8395
# ✅ Saved: submission_PolyLog_best.csv

# %%
from IPython.display import FileLink
FileLink("submission.csv")
# Out:
# C:\Users\Cun\Downloads\submission.csv

# %%
# from sklearn.svm import SVC
# import pandas as pd

# best_model = SVC(kernel="rbf", C=1.0, gamma="scale", random_state=42)
# best_model.fit(X_train, y_train)
# y_pred = best_model.predict(X_test)
# submission = pd.DataFrame({
#     "PassengerId": test_df.index,
#     "Survived": y_pred.astype(int)
# })
# submission.to_csv("submission.csv", index=False, sep=",")
# print("Saved submission.csv")

# %%
# from IPython.display import FileLink
# FileLink("submission.csv")
# Out:
# C:\Users\Cun\Downloads\submission.csv
